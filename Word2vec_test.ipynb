# %%
# import modules & set up logging
import gensim, logging
import cython
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
model = gensim.models.Word2Vec(sentences, min_count=1)

# %%
from gensim.models.word2vec import *
import os
print(os.getcwd())
class MySentences(object):
    
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield line.split()

                
sentences = LineSentence('./data/frwiki-latest-pages-articles.xml.bz2')
model = Word2Vec(sentences,size=100,min_count=10,workers=4)
model.save('/tmp/word2vec')
# Out:
# /Users/Maxime/SendIt/SFR/Blabladata

# %%
a = model.vocab['mettre']
print(a.__sizeof__())
model.vocab
# Out:
# 32
# {u'limitee': <gensim.models.word2vec.Vocab at 0x10e654050>,
#  u'savez': <gensim.models.word2vec.Vocab at 0x10dff1fd0>,
#  u'repondu': <gensim.models.word2vec.Vocab at 0x10e6d8810>,
#  u'dysfonctionnement': <gensim.models.word2vec.Vocab at 0x10e659cd0>,
#  u'pardon': <gensim.models.word2vec.Vocab at 0x10de0d810>,
#  u'veut': <gensim.models.word2vec.Vocab at 0x10e654090>,
#  u'andre': <gensim.models.word2vec.Vocab at 0x10e6d8890>,
#  u'abonne': <gensim.models.word2vec.Vocab at 0x10d75b3d0>,
#  u'travaux': <gensim.models.word2vec.Vocab at 0x10d75b590>,
#  u'aider': <gensim.models.word2vec.Vocab at 0x10e6d88d0>,
#  u'logement': <gensim.models.word2vec.Vocab at 0x10e6540d0>,
#  u'crete': <gensim.models.word2vec.Vocab at 0x10dfe2090>,
#  u'fourni': <gensim.models.word2vec.Vocab at 0x10d73fbd0>,
#  u'veux': <gensim.models.word2vec.Vocab at 0x10e654110>,
#  u'aidez': <gensim.models.word2vec.Vocab at 0x10e6d8910>,
#  u'utilisateur': <gensim.models.word2vec.Vocab at 0x10dfe20d0>,
# ...

# %%
model.most_similar(positive=['femme', 'homme'], negative=['grand'], topn=1)

# %%
[method for method in dir(a) if callable(getattr(a, method))]
# Out:
# ['__class__',
#  '__delattr__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__lt__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
model.most_similar(positive=['beau', 'beau'], negative=['beau'], topn=3)
# Out:
# [(u'didier', 0.6627337336540222),
#  (u'biais', 0.6620383262634277),
#  (u'serieux', 0.6610344648361206)]

# %%
len(model['quoi'])
# Out:
# 128

# %%
print gensim.models.word2vec.FAST_VERSION
# Out:
# 1
